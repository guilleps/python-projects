# %%
import pandas as pd
import random
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from sklearn.linear_model import LinearRegression
from fancyimpute import IterativeImputer

# %%
df_mean = pd.read_csv("C:/workspace/Python/TAREA10/data/Churn_Modelling.csv")
df_reg = pd.read_csv("C:/workspace/Python/TAREA10/data/Churn_Modelling.csv")

# %%
df = pd.read_csv("C:/workspace/Python/TAREA10/data/Churn_Modelling.csv")
df.head(6)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# 5       8  113755.78              2          1               0
#
# ...

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
## Crea un mapa de calor que visualiza los valores nulos en un DataFrame
plt.figure(figsize = (10, 8))
sb.heatmap(df.isnull(), cbar=False , cmap = 'inferno')

plt.show()

# %%
mice_imputer = IterativeImputer(max_iter=8, estimator=LinearRegression())
df_imputed_data = mice_imputer.fit_transform(df)
df_imputed_data = pd.DataFrame(df_imputed_data, columns=df.columns)
df_imputed_data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13552\2080201694.py in ?()
#       1 mice_imputer = IterativeImputer(max_iter=8, estimator=LinearRegression())
# ----> 2 df_imputed_data = mice_imputer.fit_transform(df)
#       3 df_imputed_data = pd.DataFrame(df_imputed_data, columns=df.columns)
#       4 df_imputed_data.head()
#
# c:\workspace\Python\my_venv\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     155     @wraps(f)
#     156     def wrapped(self, X, *args, **kwargs):
# --> 157         data_to_wrap = f(self, X, *args, **kwargs)
#     158         if isinstance(data_to_wrap, tuple):
#     159             # only wrap the first output for cross decomposition
#     160             return_tuple = (
#
# c:\workspace\Python\my_venv\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
# ...

# %%
df_imputed_data .isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
## Crea un mapa de calor que visualiza los valores nulos en un DataFrame
plt.figure(figsize = (10, 8))
sb.heatmap(df_imputed_data.isnull(), cbar=False , cmap = 'inferno')

plt.show()

# %%
df_imputed_data.head(12)
# Out:
#     YearsExperience   Salary
# 0          1.100000  39343.0
# 1          1.300000  46205.0
# 2          0.984145  37731.0
# 3          2.000000  43525.0
# 4          1.229278  39891.0
# 5          2.900000  56642.0
# 6          3.000000  60150.0
# 7          3.200000  54445.0
# 8          4.015859  64445.0
# 9          3.192391  57189.0
# 10         3.900000  63218.0
# 11         3.034076  55794.0

# %%
df_imputed_data.describe()
# Out:
#        YearsExperience         Salary
# count        35.000000      35.000000
# mean          6.228941   83945.600000
# std           3.696979   32162.673003
# min           0.984145   37731.000000
# 25%           3.196196   57019.000000
# 50%           5.300000   81363.000000
# 75%           9.310612  113223.500000
# max          13.500000  139465.000000
