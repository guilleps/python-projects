# %%
import pandas as pd
import random
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
df_mean = pd.read_csv("C:/workspace/Python/TAREA10/data/Salary.csv")
df_reg = pd.read_csv("C:/workspace/Python/TAREA10/data/Salary.csv")

# %%
df = pd.read_csv("C:/workspace/Python/TAREA10/data/Salary.csv")
df.head(6)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              NaN   37731
# 3              2.0   43525
# 4              NaN   39891
# 5              2.9   56642

# %%
df.isnull().sum()
# Out:
# YearsExperience    10
# Salary              0
# dtype: int64

# %%
## Crea un mapa de calor que visualiza los valores nulos en un DataFrame
plt.figure(figsize = (10, 8))
sb.heatmap(df.isnull(), cbar=False , cmap = 'inferno')

plt.show()

# %%
mice_imputer = IterativeImputer(max_iter=8, estimator=LinearRegression())
df_imputed_data = mice_imputer.fit_transform(df)
df_imputed_data = pd.DataFrame(df_imputed_data, columns=df.columns)
df_imputed_data.head()
# Out:
#    YearsExperience   Salary
# 0         1.100000  39343.0
# 1         1.300000  46205.0
# 2         0.984145  37731.0
# 3         2.000000  43525.0
# 4         1.229278  39891.0

# %%
df_imputed_data .isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
## Crea un mapa de calor que visualiza los valores nulos en un DataFrame
plt.figure(figsize = (10, 8))
sb.heatmap(df_imputed_data.isnull(), cbar=False , cmap = 'inferno')

plt.show()

# %%
df_imputed_data.head(12)
# Out:
#     YearsExperience   Salary
# 0          1.100000  39343.0
# 1          1.300000  46205.0
# 2          0.984145  37731.0
# 3          2.000000  43525.0
# 4          1.229278  39891.0
# 5          2.900000  56642.0
# 6          3.000000  60150.0
# 7          3.200000  54445.0
# 8          4.015859  64445.0
# 9          3.192391  57189.0
# 10         3.900000  63218.0
# 11         3.034076  55794.0

# %%
df_imputed_data.describe()
# Out:
#        YearsExperience         Salary
# count        35.000000      35.000000
# mean          6.228941   83945.600000
# std           3.696979   32162.673003
# min           0.984145   37731.000000
# 25%           3.196196   57019.000000
# 50%           5.300000   81363.000000
# 75%           9.310612  113223.500000
# max          13.500000  139465.000000
